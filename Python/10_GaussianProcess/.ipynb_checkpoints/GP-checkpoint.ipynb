# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import LinearColorMapper, BasicTicker, ColorBar
from bokeh.palettes import Category10
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9cbe054a-0faf-4dbf-becf-787da8841159">Loading BokehJS ...</span>
#     </div>

# %%
def plot_unit_gaussian_samples(D):
    p = figure(plot_width=800, plot_height=500, title='Samples from a unit {}D Gaussian'.format(D))

    xs = np.linspace(0, 1, D)
    for color in Category10[10]:
        ys = np.random.multivariate_normal(np.zeros(D), np.eye(D))
        p.line(xs, ys, line_width=1, color=color)
    return p

# %%
show(plot_unit_gaussian_samples(20))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ff6f9a6e-8919-44d9-9022-752fda85ad5a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ff6f9a6e-8919-44d9-9022-752fda85ad5a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ff6f9a6e-8919-44d9-9022-752fda85ad5a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ff6f9a6e-8919-44d9-9022-752fda85ad5a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"dd59ed9d-572c-40f0-9882-8a3f5547689d":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1db857e4-3ac1-4f68-b068-61d9ed846490","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2e390d2e-db5f-4cd5-812e-dad88688be13","type":"PanTool"},{"id":"a13a345b-119d-4e8c-bd97-3629f6674cea","type":"WheelZoomTool"},{"id":"ba1e3183-2d80-45e4-8412-025af0d482e1","type":"BoxZoomTool"},{"id":"d5c96d3d-a0ed-427f-b183-a52d335102f5","type":"SaveTool"},{"id":"fd775982-6fb7-4227-b077-4fb4ad52cd8f","type":"ResetTool"},{"id":"07d60f26-8929-4912-995f-6313f419e3ce","type":"HelpTool"}]},"id":"f59f11ff-98b0-4a86-bdb1-a4093984b22f","type":"Toolbar"},{"attributes":{"callback":null},"id":"c4225499-96c4-4816-963c-ae12e272c736","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAor6G8hvKqPyivobyG8ro/XkN5DeU1xD8or6G8hvLKP3kN5TWU19A/XkN5DeU11D9DeQ3lNZTXPyivobyG8to/DeU1lNdQ3j95DeU1lNfgP2wor6G8huI/XkN5DeU15D9QXkN5DeXlP0N5DeU1lOc/NpTXUF5D6T8or6G8hvLqPxrKayivoew/DeU1lNdQ7j8AAAAAAADwPw==","dtype":"float64","shape":[20]},"y":{"__ndarray__":"CqpQOqBM57/oCrN1jq/uP/jhpkILqwZAKWfiXMVe9b92fQCfqSvUv1D8iNwtgvg/AhMPWXWI3r+JViNcqgblv3hXzXJoyL2/n+ieksy30r+FdtzUmQy9v9li6n/Z1+W/61nWssA29b9LrbB2AzDQv2zF7FZvP68/0UOwe3b4AMBqtrbHLFnmv3XyDIwoWADAnoDXufhLAUAPfvb9zM/xvw==","dtype":"float64","shape":[20]}}},"id":"13f04574-596c-4c5f-84a2-6613cf3d2208","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAor6G8hvKqPyivobyG8ro/XkN5DeU1xD8or6G8hvLKP3kN5TWU19A/XkN5DeU11D9DeQ3lNZTXPyivobyG8to/DeU1lNdQ3j95DeU1lNfgP2wor6G8huI/XkN5DeU15D9QXkN5DeXlP0N5DeU1lOc/NpTXUF5D6T8or6G8hvLqPxrKayivoew/DeU1lNdQ7j8AAAAAAADwPw==","dtype":"float64","shape":[20]},"y":{"__ndarray__":"HNzVlWiz778wJc+zY13lP8eqkp6niOy/NXGOhEb24L+7cM/OFVLhP43X1GuypwHA+nK70Xbr6z9NcOEc+cgAQFvM1s7atvS/oo+jMBNf7T85z+k2AD7YPzUrTTsp7PM/GbXuvAz4tz806CHAGbPcv45W3l6klqS/L8yTD5+B6T/rK1/iWSgBwFU9yHr/LOM/nL8floJUsb+WUe1fvzjtPw==","dtype":"float64","shape":[20]}}},"id":"71697f93-c69f-47c2-8494-6d6beb96e5a1","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ff9619a2-21a1-4d8b-95af-d96423944d4a","type":"Line"},{"attributes":{"plot":null,"text":"Samples from a unit 20D Gaussian"},"id":"71919a99-c030-4ec2-adc9-d3745f3262a0","type":"Title"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"07383fff-51f8-4123-88d4-e6470db4951d","type":"Line"},{"attributes":{"line_color":{"value":"#e377c2"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b7065638-1a2b-4dc1-aede-7f0bbf7487c0","type":"Line"},{"attributes":{"callback":null},"id":"ff82c55c-f06b-4a17-9337-457887ae7c00","type":"DataRange1d"},{"attributes":{"line_color":{"value":"#9467bd"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f
type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"493c8aee-ed79-4a8a-ae67-5b565d966431","type":"Line"},{"attributes":{"plot":null,"text":"Samples from a unit 20D Gaussian"},"id":"b1b69e75-09a0-4c9a-93f2-0a45e9146d82","type":"Title"},{"attributes":{"data_source":{"id":"cf927be2-99f1-4a47-b300-0c0ad1f6f679","type":"ColumnDataSource"},"glyph":{"id":"cad27bc5-2a3a-4131-b6bf-08e2b60d4644","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"0a7c78ea-53fd-42f6-b1aa-9bde1a092353","type":"Line"},"selection_glyph":null},"id":"87cbc972-df7b-4d5e-8cee-389beb5da07c","type":"GlyphRenderer"},{"attributes":{},"id":"c84b4e8a-84cc-42f6-8806-1bfd47aa6b8a","type":"BasicTicker"},{"attributes":{"line_color":{"value":"#e377c2"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a4c69bf-54c4-473a-8869-45e5a8985aff","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"04418e8f-8d31-4387-8f45-90623890333b","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAor6G8hvKqPyivobyG8ro/XkN5DeU1xD8or6G8hvLKP3kN5TWU19A/XkN5DeU11D9DeQ3lNZTXPyivobyG8to/DeU1lNdQ3j95DeU1lNfgP2wor6G8huI/XkN5DeU15D9QXkN5DeXlP0N5DeU1lOc/NpTXUF5D6T8or6G8hvLqPxrKayivoew/DeU1lNdQ7j8AAAAAAADwPw==","dtype":"float64","shape":[20]},"y":{"__ndarray__":"h/vWTBN/7D/kzrTddNftP2cQMJxQkM8/8rbnbngDDcBgQF3bbgbSP9IMk6kfpso/r1tnr4Qi8j8kFPkv3475v24yYx7qA+g/zgwpSTR56L85IgyIb3/gvzQ ...

# %%
def k(xs, ys, sigma=1, l=1):
    """Sqared Exponential kernel as above but designed to return the whole
    covariance matrix - i.e. the pairwise covariance of the vectors xs & ys.
    Also with two parameters which are discussed at the end."""

    # Pairwise difference matrix.
    dx = np.expand_dims(xs, 1) - np.expand_dims(ys, 0)
    return (sigma ** 2) * np.exp(-((dx / l) ** 2) / 2)

def m(x):
    """The mean function. As discussed, we can let the mean always be zero."""
    return np.zeros_like(x)

# %%
N = 100
x = np.linspace(-2, 2, N)
y = np.linspace(-2, 2, N)
d = k(x, y)

color_mapper = LinearColorMapper(palette="Plasma256", low=0, high=1)

p = figure(plot_width=1000, plot_height=1000, x_range=(-2, 2), y_range=(-2, 2),
           title='Visualisation of k(x, x\')', x_axis_label='x', y_axis_label='x\'', toolbar_location=None)
p.image(image=[d], color_mapper=color_mapper, x=-2, y=-2, dw=4, dh=4)

color_bar = ColorBar(color_mapper=color_mapper, ticker=BasicTicker(),
                     label_standoff=12, border_line_color=None, location=(0,0))

p.add_layout(color_bar, 'right')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4c2f06c6-9d89-4a63-a524-7c3cb8595f85"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4c2f06c6-9d89-4a63-a524-7c3cb8595f85");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4c2f06c6-9d89-4a63-a524-7c3cb8595f85");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4c2f06c6-9d89-4a63-a524-7c3cb8595f85' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"25638ffa-9438-459f-a27b-f387a82b1449":{"roots":{"references":[{"attributes":{},"id":"3fc0a225-9a43-44e3-9228-63d0c71db36b","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"}},"id":"957c9665-af3b-4b6c-af89-3dac0ca14d2c","type":"PanTool"},{"attributes":{},"id":"4bedcf48-874c-4e59-8880-9246329d3a1d","type":"BasicTicker"},{"attributes":{"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"}},"id":"93f4e045-8ec6-4192-939e-9a3c2e1afb86","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"43eec831-7044-40ce-ba6c-379e5ec82ae8","type":"BoxAnnotation"},"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"}},"id":"c9987601-8afc-4c0a-9615-1660146561c9","type":"BoxZoomTool"},{"attributes":{},"id":"99adfbc5-cbf4-40d9-b38b-2b00f5453cd6","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"}},"id":"571b6c94-e5de-46c7-88c4-9e396994d99f","type":"SaveTool"},{"attributes":{},"id":"9a622b93-f78b-4438-9126-fffdd16a5a69","type":"BasicTickFormatter"},{"attributes":{"color_mapper":{"id":"2c2e153f-d434-4c77-aefd-19474a0d834a","type":"LinearColorMapper"},"dh":{"units":"data","value":4},"dw":{"units":"data","value":4},"image":{"field":"image"},"x":{"value":-2},"y":{"value":-2}},"id":"90b8e701-2134-430e-acfe-69291d37b073","type":"Image"},{"attributes":{"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"}},"id":"a8175ad1-50c2-45d4-9b35-c1d93cf92157","type":"ResetTool"},{"attributes":{"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"}},"id":"0db784aa-2c81-4335-b128-0b459c23b707","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"fec33552-9583-485a-a1f0-6322b03801f2","type":"BasicTicker"}},"id":"c799368a-05bc-410c-98a8-c7408b6c87ca","type":"Grid"},{"attributes":{"color_mapper":{"id":"2c2e153f-d434-4c77-aefd-19474a0d834a","type":"LinearColorMapper"},"formatter":{"id":"9a622b93-f78b-4438-9126-fffdd16a5a69","type":"BasicTickFormatter"},"label_standoff":12,"location":[0,0],"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"4bedcf48-874c-4e59-8880-9246329d3a1d","type":"BasicTicker"}},"id":"f59d7772-3ca7-4d1c-9c94-4b36e30bebd4","type":"ColorBar"},{"attributes":{"plot":null,"text":"Visualisation of k(x, x')"},"id":"5195878e-adee-4a00-933c-3b053f95592d","type":"Title"},{"attributes":{"data_source":{"id":"ee3cd1a4-daa1-4096-aab3-c43746a2e484","type":"ColumnDataSource"},"glyph":{"id":"56e26303-45de-4347-aeac-a23634d51f39","type":"Image"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"90b8e701-2134-430e-acfe-69291d37b073","type":"Image"},"selection_glyph":null},"id":"40cb66cd-d23d-4122-a67d-750bf847ba00","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"43eec831-7044-40ce-ba6c-379e5ec82ae8","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["image"],"data":{"image":[{"__ndarray__":"...","dtype":"float64","shape":[100,100]}]}},"id":"ee3cd1a4-daa1-4096-aab3-c43746a2e484","type":"ColumnDataSource"},{"attributes":{"axis_label":"x","formatter":{"id":"99adfbc5-cbf4-40d9-b38b-2b00f5453cd6","type":"BasicTickFormatter"},"plot":{"id":"b4377d7b-9bdb-4cfc-bc79-fb708ee19fbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"53a2d4aa-5d28-4c68-97f1-df50ef1cfaa5","type":"BasicTicker"}},"id":"4cf6be77-d9a4-4301-a295-bdcf2cb608d8","type":"LinearAxis"},{"attributes":{"callback":null,"end":2,"star ...

# %%
p = figure(plot_width=800, plot_height=500)
D = 20
xs = np.linspace(0, 1, D)
for color in Category10[10]:
    ys = np.random.multivariate_normal(m(xs), k(xs, xs))
    p.circle(xs, ys, size=5, color=color)
    p.line(xs, ys, line_width=1, color=color)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a583fcfe-4dd2-47e7-be51-351eda1a6e28"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a583fcfe-4dd2-47e7-be51-351eda1a6e28");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a583fcfe-4dd2-47e7-be51-351eda1a6e28");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a583fcfe-4dd2-47e7-be51-351eda1a6e28' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"31026ce3-2992-4d93-b37b-537a3774b0c1":{"roots":{"references":[{"attributes":{"overlay":{"id":"f8584794-f912-4c91-9015-d99859b464bd","type":"BoxAnnotation"},"plot":{"id":"d9e250dc-7489-4e14-9d71-f3d9e09a2a1c","subtype":"Figure","type":"Plot"}},"id":"dd71b267-4823-46dc-bfb9-d32afa8c46e4","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"AAAAAAAAAAAor6G8hvKqPyivobyG8ro/XkN5DeU1xD8or6G8hvLKP3kN5TWU19A/XkN5DeU11D9DeQ3lNZTXPyivobyG8to/DeU1lNdQ3j95DeU1lNfgP2wor6G8huI/XkN5DeU15D9QXkN5DeXlP0N5DeU1lOc/NpTXUF5D6T8or6G8hvLqPxrKayivoew/DeU1lNdQ7j8AAAAAAADwPw==","dtype":"float64","shape":[20]},"y":{"__ndarray__":
# %%
# coefs[i] is the coefficient of x^i
coefs = [6, -2.5, -2.4, -0.1, 0.2, 0.03]

def f(x):
    total = 0
    for exp, coef in enumerate(coefs):
        total += coef * (x ** exp)
    return total

xs = np.linspace(-5.0, 3.5, 100)
ys = f(xs)

p = figure(plot_width=800, plot_height=400, x_axis_label='x',
           y_axis_label='f(x)', title='The hidden function f(x)')
p.line(xs, ys, line_width=2)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4ac86523-7560-484d-9d13-337ef3c5962a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4ac86523-7560-484d-9d13-337ef3c5962a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4ac86523-7560-484d-9d13-337ef3c5962a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4ac86523-7560-484d-9d13-337ef3c5962a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a956f1f8-b8be-4ae9-8762-bf8282b76858":{"roots":{"references":[{"attributes":{"below":[{"id":"a5b8a0a8-3a21-4aa9-a1f3-5bd543d330a1","type":"LinearAxis"}],"left":[{"id":"516f06d9-f480-4bad-9492-d08e7b92cbfc","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"a5b8a0a8-3a21-4aa9-a1f3-5bd543d330a1","type":"LinearAxis"},{"id":"9c7eca95-ae80-4266-8c46-c7eee532227e","type":"Grid"},{"id":"516f06d9-f480-4bad-9492-d08e7b92cbfc","type":"LinearAxis"},{"id":"2d18fdc7-5a09-4624-8859-e2e7dae24714","type":"Grid"},{"id":"21a6639f-88fe-4a81-9f01-7ca380ebda26","type":"BoxAnnotation"},{"id":"bf9d5be1-cd59-419e-95ba-b85046f9f018","type":"GlyphRenderer"}],"title":{"id":"3121f402-8c69-407b-b357-0384401e4a4f","type":"Title"},"tool_events":{"id":"3ec20828-d321-48eb-bef6-040024ee3dd2","type":"ToolEvents"},"toolbar":{"id":"4e7d613f-5d67-4d3a-9108-6b126632d7a4","type":"Toolbar"},"x_range":{"id":"83f91755-6eb3-440d-b2b8-4cdb67755f2c","type":"DataRange1d"},"y_range":{"id":"f35d2afa-844d-48a5-bcba-d279a9f2802c","type":"DataRange1d"}},"id":"8b45ec35-b8ec-44f8-b39a-5b78ffbe6a3c","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"5ee880f6-5c6b-4cad-aac8-54104051989b","type":"BasicTickFormatter"},{"attributes":{},"id":"3ec20828-d321-48eb-bef6-040024ee3dd2","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d1464406-6cf3-474e-899a-e2db8b6ed30d","type":"PanTool"},{"id":"229feffe-3f18-4aaa-b093-95134bfa7bbd","type":"WheelZoomTool"},{"id":"74658e18-a306-4c72-a6c4-d8b358d8f3ff","type":"BoxZoomTool"},{"id":"fb8fac5c-ab36-4c54-bb04-69dbfdfed5c1","type":"SaveTool"},{"id":"4c9730c1-900e-4072-b225-284fcb232dfd","type":"ResetTool"},{"id":"2f8f79f7-63d2-4eb0-888a-ca40007bdbbb","type":"HelpTool"}]},"id":"4e7d613f-5d67-4d3a-9108-6b126632d7a4","type":"Toolbar"},{"attributes":{"callback":null},"id":"83f91755-6eb3-440d-b2b8-4cdb67755f2c","type":"DataRange1d"},{"attributes":{"axis_label":"f(x)","formatter":{"id":"97b7d67f-746c-43bd-9d2d-409536602114","type":"BasicTickFormatter"},"plot":{"id":"8b45ec35-b8ec-44f8-b39a-5b78ffbe6a3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"742065ff-15fd-4eb3-b70f-7dcef7e1de66","type":"BasicTicker"}},"id":"516f06d9-f480-4bad-9492-d08e7b92cbfc","type":"LinearAxis"},{"attributes":{"plot":{"id":"8b45ec35-b8ec-44f8-b39a-5b78ffbe6a3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5dc6371-63ee-4bd0-817d-c6e3384243c1","type":"BasicTicker"}},"id":"9c7eca95-ae80-4266-8c46-c7eee532227e","type":"Grid"},{"attributes":{},"id":"e5dc6371-63ee-4bd0-817d-c6e3384243c1","type":"BasicTicker"},{"attributes":{"axis_label":"x","formatter":{"id":"5ee880f6-5c6b-4cad-aac8-54104051989b","type":"BasicTickFormatter"},"plot":{"id":"8b45ec35-b8ec-44f8-b39a-5b78ffbe6a3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5dc6371-63ee-4bd0-817d-c6e3384243c1","type":"BasicTicker"}},"id":"a5b8a0a8-3a21-4aa9-a1f3-5bd543d330a1","type":"LinearAxis"},{"attributes":{"plot":{"id":"8b45ec35-b8ec-44f8-b39a-5b78ffbe6a3c","subtype":"Figure","type":"Plot"}},"id":"2f8f79f7-63d2-4eb0-888a-ca40007bdbbb","type":"HelpTool"},{"attributes":{"callback":null},"id":"f35d2afa-844d-48a5-bcba-d279a9f2802c","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"8b45ec35-b8ec-44f8-b39a-5b78ffbe6a3c","subtype":"Figure","type":"Plot"},"ticker":{"id":"742065ff-15fd-4eb3-b70f-7dcef7e1de66","type":"BasicTicker"}},"id":"2d18fdc7-5a09-4624-8859-e2e7dae24714","type":"Grid"},{"attributes":{"plot":{"id":"8b45ec35-b8ec-44f8-b39a-5b78ffbe6a3c","subtype":"Figure","type":"Plot"}},"id":"4c9730c1-900e-4072-b225-284fcb232dfd","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"21a6639f-88fe- ...

# %%
x_obs = np.array([-4, -1.5, 0, 1.5, 2.5, 2.7])
y_obs = f(x_obs)

x_s = np.linspace(-8, 7, 80)

# %%
K = k(x_obs, x_obs)
K_s = k(x_obs, x_s)
K_ss = k(x_s, x_s)

K_sTKinv = np.matmul(K_s.T, np.linalg.pinv(K))

mu_s = m(x_s) + np.matmul(K_sTKinv, y_obs - m(x_obs))
Sigma_s = K_ss - np.matmul(K_sTKinv, K_s)

# %%
p = figure(plot_width=800, plot_height=600, y_range=(-7, 8))

y_true = f(x_s)
p.line(x_s, y_true, line_width=3, color='black', alpha=0.4,
       line_dash='dashed', legend='True f(x)')

p.cross(x_obs, y_obs, size=20, legend='Training data')

stds = np.sqrt(Sigma_s.diagonal())
err_xs = np.concatenate((x_s, np.flip(x_s, 0)))
err_ys = np.concatenate((mu_s + 2 * stds, np.flip(mu_s - 2 * stds, 0)))
p.patch(err_xs, err_ys, alpha=0.2, line_width=0, color='grey',
        legend='Uncertainty')

for color in Category10[4]:
    y_s = np.random.multivariate_normal(mu_s, Sigma_s)
    p.line(x_s, y_s, line_width=1, color=color)

p.line(x_s, mu_s, line_width=3, color='blue', alpha=0.4, legend='Mean')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b15a733d-712f-49b8-8665-51cb5281b74c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b15a733d-712f-49b8-8665-51cb5281b74c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b15a733d-712f-49b8-8665-51cb5281b74c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b15a733d-712f-49b8-8665-51cb5281b74c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e5fc861a-f1eb-47d1-924b-0fb9439833f0":{"roots":{"references":[{"attributes":{"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f9f3699-a4b0-497c-8d36-7bbf013f8300","type":"BasicTicker"}},"id":"a1e98191-1773-4171-a328-6f339c183327","type":"Grid"},{"attributes":{"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"}},"id":"25d83254-e7bc-412a-8088-004849ecd399","type":"ResetTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":20},"x":{"field":"x"},"y":{"field":"y"}},"id":"10e22dbf-38fa-4816-9ac1-20d8d7ad336d","type":"Cross"},{"attributes":{},"id":"e7f4b643-b6f1-4b51-83d1-b3b95669eae4","type":"BasicTicker"},{"attributes":{},"id":"f59a4a07-8f5a-4d32-9178-93b6a25d8a7f","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"Mean"},"renderers":[{"id":"d82bb394-d75d-49b5-ab09-d875f4c33343","type":"GlyphRenderer"}]},"id":"e3eda5ca-d695-4ab7-a895-7f5c5f0478a9","type":"LegendItem"},{"attributes":{"label":{"value":"Training data"},"renderers":[{"id":"4ba01a7a-51fc-45bd-abc1-b7be6ed1ed2a","type":"GlyphRenderer"}]},"id":"4b96fd9a-38da-4356-8c7c-2a0e74ea3d98","type":"LegendItem"},{"attributes":{"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"}},"id":"62c77c07-ff0c-4dc4-9771-1e8532e1b7d4","type":"HelpTool"},{"attributes":{"overlay":{"id":"c459e7f7-172e-445f-a8d0-316be7e27cad","type":"BoxAnnotation"},"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"}},"id":"1258fa88-390a-4a2a-aeb6-11c31c677fdc","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"}},"id":"ea79d44d-3c53-41b6-8ad8-75b03df3d5e7","type":"SaveTool"},{"attributes":{"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"}},"id":"aebe6f64-09a9-4b0d-bf4a-e6e9df5acd1e","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c459e7f7-172e-445f-a8d0-316be7e27cad","type":"BoxAnnotation"},{"attributes":{"items":[{"id":"c9b5ad4a-3374-46cc-9941-bfc5fff9cb6c","type":"LegendItem"},{"id":"4b96fd9a-38da-4356-8c7c-2a0e74ea3d98","type":"LegendItem"},{"id":"cddc102d-bf0b-4bb9-a229-9fdacf36c679","type":"LegendItem"},{"id":"e3eda5ca-d695-4ab7-a895-7f5c5f0478a9","type":"LegendItem"}],"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"}},"id":"9a0d5be4-0ec4-45dc-820e-f1b2b910f30e","type":"Legend"},{"attributes":{},"id":"9f9f3699-a4b0-497c-8d36-7bbf013f8300","type":"BasicTicker"},{"attributes":{},"id":"8e703a11-770d-4a84-be50-5213da51609d","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"1c1d37f2-2553-4cef-b926-a5f213306cf3","subtype":"Figure","type":"Plot"}},"id":"b3d744f8-4052-4a72-a0b8-0a6cd006a0ed","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.2},"fill_color":{"value":"grey"},"line_alpha":{"value":0.2},"line_color":{"value":"grey"},"line_width":{"value":0},"x":{"field":"x"},"y":{"field":"y"}},"id":"53a542c4-173a-4dfa-b6ed-a1b3688e9574","type":"Patch"},{"attributes":{"data_source":{"id":"a952940d-3a41-41a9-96e7-9de28c3c9c9d","type":"ColumnDataSource"},"glyph":{"id":"45e1d04c-87b1-4455-8639-f9b4e78f68f4","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c143d139-5840-4c59-90fa-0e4b5b15aaf7","type":"Line"},"selection_glyph":null},"id":"af632e89-11b4-481d-b61c-0b43567e5534","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"02d4ff93-07bc-4a1c-b0a2-ae60ebc6dbc2","type":"ColumnDataSource"},"glyph":{"id":"53a542c4-173a-4dfa-b6ed-a1b3688e9574","type":"Patch"},"hover_glyph":null,"m ...
